# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9ae83ed6-2b6b-4fb8-ac0a-f4aef4868954" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ae83ed6-2b6b-4fb8-ac0a-f4aef4868954">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sunny-right.mp4 to sunny-right.mp4
# Saving sunny-left.mp4 to sunny-left.mp4
# Saving rainy-right.mp4 to rainy-right.mp4
# Saving rainy-left.mp4 to rainy-left.mp4
# Saving foggy-right.mp4 to foggy-right.mp4
# Saving foggy-left.mp4 to foggy-left.mp4
# Saving cloudy-right.mp4 to cloudy-right.mp4
# Saving cloudy-left.mp4 to cloudy-left.mp4

# %%
import cv2
import numpy as np
import time
start_time = time.time()
cap_l = cv2.VideoCapture('/content/sunny-left.mp4')
cap_r = cv2.VideoCapture('/content/sunny-right.mp4')
brisk = cv2.BRISK_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l = brisk.detect(gray_l,None)
      kp_r = brisk.detect(gray_r,None)

      kp_l,des_l = brisk.compute(gray_l,kp_l)
      kp_r,des_r = brisk.compute(gray_r,kp_r)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("brisk_sunny_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("brisk_sunny_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("brisk_sunny_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("brisk_sunny_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 419.168
# Avg. Keypoints Right: 403.664
# Avg. Matches: 204.734
# Avg. fps: 27.43
# Execution Time: 23.8102445602417 secs
# Finished!

# %%
import cv2
import numpy as np
import time
start_time = time.time()
cap_l = cv2.VideoCapture('/content/foggy-left.mp4')
cap_r = cv2.VideoCapture('/content/foggy-right.mp4')
brisk = cv2.BRISK_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l = brisk.detect(gray_l,None)
      kp_r = brisk.detect(gray_r,None)

      kp_l,des_l = brisk.compute(gray_l,kp_l)
      kp_r,des_r = brisk.compute(gray_r,kp_r)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("brisk_foggy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("brisk_foggy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("brisk_foggy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("brisk_foggy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 158.728
# Avg. Keypoints Right: 162.148
# Avg. Matches: 91.78
# Avg. fps: 51.23
# Execution Time: 12.815476417541504 secs
# Finished!

# %%
import cv2
import numpy as np
import time
start_time = time.time()
cap_l = cv2.VideoCapture('/content/rainy-left.mp4')
cap_r = cv2.VideoCapture('/content/rainy-right.mp4')
brisk = cv2.BRISK_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l = brisk.detect(gray_l,None)
      kp_r = brisk.detect(gray_r,None)

      kp_l,des_l = brisk.compute(gray_l,kp_l)
      kp_r,des_r = brisk.compute(gray_r,kp_r)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("brisk_rainy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("brisk_rainy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("brisk_rainy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("brisk_rainy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 114.28
# Avg. Keypoints Right: 123.278
# Avg. Matches: 58.076
# Avg. fps: 60.812
# Execution Time: 11.104840278625488 secs
# Finished!

# %%
import cv2
import numpy as np
import time
start_time = time.time()
cap_l = cv2.VideoCapture('/content/cloudy-left.mp4')
cap_r = cv2.VideoCapture('/content/cloudy-right.mp4')
brisk = cv2.BRISK_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l = brisk.detect(gray_l,None)
      kp_r = brisk.detect(gray_r,None)

      kp_l,des_l = brisk.compute(gray_l,kp_l)
      kp_r,des_r = brisk.compute(gray_r,kp_r)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("brisk_cloudy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("brisk_cloudy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("brisk_cloudy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("brisk_cloudy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 284.404
# Avg. Keypoints Right: 266.93
# Avg. Matches: 143.632
# Avg. fps: 36.906
# Execution Time: 17.42556071281433 secs
# Finished!
